# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# - **Cover page**
# ### Canada’s skilled worker immigration program

# %% [markdown]
# ![Image of Yaktocat](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRgxGE0Wqx9tFC_vfgYjPNPo39oQIMxipRhL1QN5l_apiJk3Xbm0A)

# %% [markdown]
# - **Introductory section**
#
# <center>Each year the Canadian government enables skilled workers worldwide to become Canadian citizens. Of course in order to become resident the candidates should meet certain criteria that attest their qualification and eligibility to stay and work in Canada.
#
# One can probably imagine how hard is for any newcomer to find its place in a new country, new city and new environment at all. Skilled experts usually receive higher income than average so they normally prefer to live in good neighborhoods with clean streets, fancy restaurants, reputable schools etc. Finding such neighborhood is usually their primary goal when arriving at the new place and they are ready to pay more but to receive proper living conditions.
#
# **Problem statement and target group identification**
#
# The present study will be examining the opportunities for such skilled immigrants to find their dream home when moving to Canada. The Canadian city chosen for this project is Toronto because it is large enough, offers many opportunities, it is multiethnic and serves as an industry and economic capital of the country.
#
# **Data section**
#
# Considering the fact that the analysis will be on Toronto's job market data it is clear that will be used dataset which was applied in the previous coursework.
#
# The exact link directing to that data is: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
# In order to get the geographic coordinates of the neighborhoods the following link was applied: http://cocl.us/Geospatial_data
#
# Last but not least Foursquare developer dataset was retrieved from their site. It is a really handy source of data related with various venues</center>

# %%
#import the necessory libraries
import numpy as np
import pandas as pd
import json
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
# !conda install -c conda-forge folium=0.5.0 --yes
import folium

#importing the datasets
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# - **Methodology section**
#
# The applied methodology will be in accordance with that used during the Capstone module.
#
# The data for the present research is primary and the main sources are public: wikipedia, foursquare, etc.
#
#
# The proposed action plan and applied code may be seen below:

# %% [markdown]
# - Downloading and manipulating raw data for Toronto's neighborhoods;

# %%
#download and manipulate the data
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
table = pd.read_html(url,header=[0])
df = table[0]
df.head()

#clean and rename
df = df.rename(index=str, columns={'Postcode':'PostalCode','Neighbourhood':'Neighborhood'})
df.head()

df = df[df.Borough !='Not assigned']
df.reset_index(drop=True,inplace=True)
df.head()

#group data
df = df.groupby('PostalCode',as_index=False).agg(lambda x: ','.join(set(x.dropna())))

df.loc[df['Neighborhood'] == 'Not assigned','Neighborhood'] = df['Borough']
df.head()
# Out:
#   PostalCode      Borough                          Neighborhood
# 0        M1B  Scarborough                         Malvern,Rouge
# 1        M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2        M1E  Scarborough       Morningside,Guildwood,West Hill
# 3        M1G  Scarborough                                Woburn
# 4        M1H  Scarborough                             Cedarbrae

# %% [markdown]
# - Downloading and manipulating Toronto's coordinates data;

# %%
#Add the file with coordinates
df1 = pd.read_csv('http://cocl.us/Geospatial_data')

# #Rename columns
df1.columns = ['PostalCode','Latitude','Longitude']
df1.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %% [markdown]
# - Mapping the data with its geographic coordinates: latitude and longitude;

# %%
#Use geopy library to get the latitude and longitude values of Toronto.
address = 'Toronto'
geolocator = Nominatim(user_agent="Presiyan Tsankov")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

neighborhoods = df.join(df1.set_index('PostalCode'), on='PostalCode')
neighborhoods.head()
# Out:
#   PostalCode      Borough                          Neighborhood   Latitude  \
# 0        M1B  Scarborough                         Malvern,Rouge  43.806686
# 1        M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2        M1E  Scarborough       Morningside,Guildwood,West Hill  43.763573
# 3        M1G  Scarborough                                Woburn  43.770992
# 4        M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# - Third step is gonna be retrieving data from Foursquare containing information about venues with their characteristics and plotting them on the map of Toronto;

# %%
# @hidden_cell
Client_ID="QJFVQGDKNATGS52DNADAKKBCPXOZXYG3MTJYRUTUMOFPPYCM"
Client_Secret="ESMJIGS3YLJWBZUIQJASWB2VFLYOWEOW55HKPYP2TANOQGPY"
VERSION = '20180605'

#Create a map of Toronto with neighborhoods superimposed on top
toronto_map = folium.Map(location=[latitude, longitude], zoom_start=10)
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(toronto_map)  
    
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - Afterwards the existing venue information should be further elaborated in order to find specific data patterns and allocate the venues into respective neighborhoods;

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=800 , LIMIT = 200):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            Client_ID, 
            Client_Secret, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        results = requests.get(url).json()["response"]['groups'][0]['items']
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

toronto_data = neighborhoods.copy()
toronto_venues = getNearbyVenues(names=toronto_data['Neighborhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )

print(toronto_venues.shape)
toronto_venues.head()

toronto_venues.groupby('Neighborhood').count().head()

print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# (3967, 7)
# There are 332 uniques categories.

# %% [markdown]
# *Analyze Each Neighborhood*

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]
toronto_onehot.head()

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.head()

#Create new dataframe and display the top 10 venues for each neighborhood.

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    return row_categories_sorted.index.values[0:num_top_venues]


num_top_venues = 10
indicators = ['st', 'nd', 'rd']
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                             Adelaide,Richmond,King                  Café
# 1                                          Agincourt    Chinese Restaurant
# 2  Agincourt North,Steeles East,L'Amoreaux East,M...  Fast Food Restaurant
# 3                              Alderwood,Long Branch           Pizza Place
# 4                                    Bayview Village   Japanese Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Coffee Shop                 Hotel   American Restaurant
# 1         Shopping Mall   Shanghai Restaurant       Motorcycle Shop
# 2           Pizza Place                  Park    Chinese Restaurant
# 3           Coffee Shop           Gas Station                   Pub
# 4                  Bank            Skate Park                  Café
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0       Thai Restaurant               Theater                   Bar
# 1           Supermarket        Sandwich Place        Discount Store
# 2             BBQ Joint   Fried Chicken Joint           Coffee Shop
# 3              Pharmacy                  Park     Convenience Store
# 4          Skating Rink         Grocery Store     Convenience Store
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0          Concert Hall            Steakhouse              Gastropub
# 1   American Restaurant                Lounge       Malay Restaurant
# 2              Pharmacy  Caribbean Restaurant           Noodle House
# 3        Sandwich Place          Dance Studio           Skating Rink
# 4    Chinese Restaurant            Restaurant          Shopping Mall

# %% [markdown]
# - Grouping venues with K-mean cluster algorythm

# %% [markdown]
# *Clustering using k = 5*

# %%
kclusters = 5
toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=42).fit(toronto_grouped_clustering)
labels = kmeans.labels_
labels = labels.tolist()
labels.append(1)
labels.append(2)
labels.append(3)
labels.append(4)
labels.append(0)
labels.append(1)

toronto_merged = toronto_data
toronto_merged['Cluster Labels'] = pd.Series(labels)

toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
toronto_merged.head()
# Out:
#   PostalCode      Borough                          Neighborhood   Latitude  \
# 0        M1B  Scarborough                         Malvern,Rouge  43.806686
# 1        M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2        M1E  Scarborough       Morningside,Guildwood,West Hill  43.763573
# 3        M1G  Scarborough                                Woburn  43.770992
# 4        M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.194353               3  Fast Food Restaurant           Coffee Shop
# 1 -79.160497               3        Breakfast Spot    Italian Restaurant
# 2 -79.188711               4           Pizza Place           Coffee Shop
# 3 -79.216917               4           Coffee Shop                  Park
# 4 -79.239476               3           Coffee Shop                Bakery
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0    Chinese Restaurant                   Spa     Martial Arts Dojo
# 1          Burger Joint                   Bar         Women's Store
# 2  Fast Food Restaurant      Greek Restaurant              Pharmacy
# 3      Business Service   Dumpling Restaurant    Dim Sum Restaurant
# 4     Indian Restaurant           Yoga Studio   Rental Car Location
#
#            6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0  Paper / Office Supplies Store            Hobby Shop    African Restaurant
# 1              Electronics Store              Dive Bar               Dog Run
# 2                     Sports Bar           Supermarket   Fried Chicken Joint
# 3                          Diner        Discount Store              Dive Bar
# 4                   Burger Joint              Bus Line           Flower Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 0      Community Center                Dog Run
# 1      Doner Restaurant             Donut Shop
# 2            Beer Store          Grocery Store
# 3               Dog Run       Doner Restaurant
# 4           Music Store                 Lounge

# %% [markdown]
# *Showing the identified clusters*

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# *Examine Cluster 0*

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0,toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 40  East York               0                  Café           Pizza Place
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 40           Coffee Shop      Greek Restaurant       Thai Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 40                  Park        Breakfast Spot             Gastropub
#
#    9th Most Common Venue 10th Most Common Venue
# 40              Beer Bar   Ethiopian Restaurant

# %% [markdown]
# *Examine Cluster 1*

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1,toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 9         Scarborough               1       College Stadium
# 27         North York               1           Coffee Shop
# 39          East York               1     Indian Restaurant
# 43       East Toronto               1                  Café
# 64    Central Toronto               1           Coffee Shop
# 69   Downtown Toronto               1           Coffee Shop
# 77       West Toronto               1                  Café
# 79         North York               1                Bakery
# 88          Etobicoke               1                  Café
# 96         North York               1                Bakery
# 99          Etobicoke               1           Pizza Place
# 101         Etobicoke               1           Pizza Place
#
#          2nd Most Common Venue       3rd Most Common Venue  \
# 9            Convenience Store                Skating Rink
# 27                         Gym            Asian Restaurant
# 39                 Coffee Shop           Afghan Restaurant
# 43                      Bakery                 Coffee Shop
# 64          Italian Restaurant                Dance Studio
# 69                        Café                  Restaurant
# 77                         Bar                  Restaurant
# 79                        Park  Construction & Landscaping
# 88          Mexican Restaurant        Fast Food Restaurant
# 96         Empanada Restaurant                 Pizza Place
# 99   Middle Eastern Restaurant                 Golf Course
# 101              Grocery Store                    Pharmacy
#
#     4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 9                    Bank                 Diner                  Café
# 27             Beer Store   Japanese Restaurant         Deli / Bodega
# 39     Turkish Restaurant           Yoga Studio              Pharmacy
# 43                    Bar                 Diner   American Restaurant
# 64                   Café                Bakery                  Bank
# 69     Italian Restaurant   Japanese Restaurant                 Hotel
# 77                 Bakery          Cocktail Bar           Men's Store
# 79           Tennis Court         Women's Store                 Diner
# 88         Sandwich Place                Bakery   Fried Chicken Joint
# 96      Electronics Store        Discount Store              Dive Bar
# 99         Discount Store           Supermarket          Intersection
# 101        Sandwich Place          Liquor Store            Beer Store
#
#      7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 9    General Entertainment                  Park       Thai Restaurant
# 27              Restaurant          Dance Studio                Office
# 39                    Park            Restaurant        Sandwich Place
# 43        Sushi Restaurant    Italian Restaurant                  Park
# 64               Gastropub   Japanese Restaurant                  Park
# 69                  Bakery                   Pub    Seafood Restaurant
# 77             Coffee Shop    Italian Restaurant      Asian Restaurant
# 79          Discount Store              Dive Bar               Dog Run
# 88            Dessert Shop              Bus Stop      Asian Restaurant
# 96                 Dog Run      Doner Restaurant            Donut Shop
# 99          Ice Cream Shop    Chinese Restaurant        Sandwich Place
# 101    Fried Chicken Joint           Coffee Shop  Fast Food Restaurant
#
#             10th Most Common Venue
# 9       Construction & Landscaping
# 27              Italian Restaurant
# 39                    Burger Joint
# 43                         Brewery
# 64              Chinese Restaurant
# 69                       Gastropub
# 77   Vegetarian / Vegan Restaurant
# 79                Doner Restaurant
# 88              Italian Restaurant
# 96             Dumpling Restaurant
# 99                     Coffee Shop
# 101                 Hardware Store

# %% [markdown]
# *Examine Cluster 2*

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2,toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 65   Central Toronto               2                  Café
# 102        Etobicoke               2                   NaN
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 65            Coffee Shop           Pizza Place    Italian Restaurant
# 102                   NaN                   NaN                   NaN
#
#     5th Most Common Venue 6th Most Common Venue  \
# 65         Sandwich Place                   Pub
# 102                   NaN                   NaN
#
#              7th Most Common Venue 8th Most Common Venue  \
# 65   Vegetarian / Vegan Restaurant   American Restaurant
# 102                            NaN                   NaN
#
#     9th Most Common Venue 10th Most Common Venue
# 65           Burger Joint             Restaurant
# 102                   NaN                    NaN

# %% [markdown]
# *Examine Cluster 3*

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3,toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels   1st Most Common Venue  \
# 0         Scarborough               3    Fast Food Restaurant
# 1         Scarborough               3          Breakfast Spot
# 4         Scarborough               3             Coffee Shop
# 5         Scarborough               3    Fast Food Restaurant
# 6         Scarborough               3             Coffee Shop
# 7         Scarborough               3                   Diner
# 8         Scarborough               3    Fast Food Restaurant
# 10        Scarborough               3  Furniture / Home Store
# 11        Scarborough               3                     Bar
# 12        Scarborough               3      Chinese Restaurant
# 13        Scarborough               3             Pizza Place
# 14        Scarborough               3    Fast Food Restaurant
# 15        Scarborough               3    Fast Food Restaurant
# 17         North York               3                Pharmacy
# 18         North York               3             Coffee Shop
# 19         North York               3     Japanese Restaurant
# 20         North York               3                    Pool
# 21         North York               3       Korean Restaurant
# 22         North York               3             Pizza Place
# 23         North York               3               Pet Store
# 24         North York               3             Coffee Shop
# 28         North York               3             Pizza Place
# 29         North York               3          Sandwich Place
# 30         North York               3             Coffee Shop
# 31         North York               3                    Park
# 32         North York               3   Vietnamese Restaurant
# 33         North York               3             Pizza Place
# 34         North York               3                    Café
# 35          East York               3    Fast Food Restaurant
# 36          East York               3            Skating Rink
# ..                ...             ...                     ...
# 53   Downtown Toronto               3             Coffee Shop
# 56   Downtown Toronto               3                    Café
# 58   Downtown Toronto               3                    Café
# 59   Downtown Toronto               3             Coffee Shop
# 60   Downtown Toronto               3                   Hotel
# 61   Downtown Toronto               3             Coffee Shop
# 63    Central Toronto               3       Health Food Store
# 66   Downtown Toronto               3                    Café
# 67   Downtown Toronto               3                    Café
# 70   Downtown Toronto               3             Coffee Shop
# 71         North York               3          Clothing Store
# 72         North York               3           Grocery Store
# 73               York               3             Coffee Shop
# 74               York               3                    Park
# 75   Downtown Toronto               3       Korean Restaurant
# 78       West Toronto               3             Coffee Shop
# 80               York               3       Convenience Store
# 81               York               3             Pizza Place
# 82       West Toronto               3                    Café
# 83       West Toronto               3                     Bar
# 84       West Toronto               3             Coffee Shop
# 85       Queen's Park               3             Coffee Shop
# 86        Mississauga               3      Chinese Restaurant
# 87       East Toronto               3    Fast Food Restaurant
# 89          Etobicoke               3             Pizza Place
# 92          Etobicoke               3               BBQ Joint
# 93          Etobicoke               3                Pharmacy
# 95          Etobicoke               3       Electronics Store
# 98               York               3       Convenience Store
# 100         Etobicoke               3      Chinese Restaurant
#
#           2nd Most Common Venue          3rd Most Common Venue  \
# 0                   Coffee Shop             Chinese Restaurant
# 1            Italian Restaurant                   Burger Joint
# 4                        Bakery              Indian Restaurant
# 5                Sandwich Place                    Pizza Place
# 6                Discount Store             Chinese Restaurant
# 7                      Bus Line                    Coffee Shop
# 8                   Pizza Place                    Wings Joint
# 10            Electronics Store              Indian Restaurant
# 11                   Restaurant             Seafood Restaurant
# 12                Shopping Mall            Shanghai Restaurant
# 13                     Pharmacy                    Coffee Shop
# 14                  Pizza Place                           Park
# 15           Chinese Restaurant                       Pharmacy
# 17                         Park                    Coffee Shop
# 18               Clothing Store            Japanese Restaurant
# 19                         Bank                     Skate Park
# 20                         Park                  Deli / Bodega
# 21                  Coffee Shop                          Trail
# 22          Japanese Restaurant                    Coffee Shop
# 23                         Park                            Gym
# 24                  Pizza Place                  Grocery Store
# 28                  Coffee Shop                           Park
# 29       Furniture / Home Store                    Pizza Place
# 30        Vietnamese Restaurant                        Airport
# 31                  Coffee Shop                    Pizza Place
# 32               Baseball Field                       Pharmacy
# 33         Fast Food Restaurant                  Grocery Store
# 34        Portuguese Restaurant                   Hockey Arena
# 35                      Brewery                    Pizza Place
# 36                         Park                            Spa
# ..                          ...                            ...
# 53                         Park                     Restaurant
# 56                  Coffee Shop                          Hotel
# 58                  Coffee Shop                          Hotel
# 59                        Hotel             Italian Restaurant
# 60                  Coffee Shop                           Café
# 61                        Hotel                           Café
# 63                   Playground                      Pet Store
# 66                  Coffee Shop                     Restaurant
# 67                          Bar  Vegetarian / Vegan Restaurant
# 70                         Café                          Hotel
# 71       Furniture / Home Store             Athletics & Sports
# 72                  Coffee Shop           Fast Food Restaurant
# 73    Middle Eastern Restaurant                           Park
# 74                     Pharmacy                  Women's Store
# 75                  Coffee Shop                  Grocery Store
# 78                          Bar                           Café
# 80   Construction & Landscaping                     Restaurant
# 81                      Brewery                    Coffee Shop
# 82                          Bar             Italian Restaurant
# 83                  Pizza Place                Thai Restaurant
# 84                         Café                    Pizza Place
# 85                    Gastropub                   Burger Joint
# 86                  Coffee Shop                          Hotel
# 87                          Bar                  Grocery Store
# 89                  Coffee Shop                    Gas Station
# 92         Gym / Fitness Center                    Coffee Shop
# 93                         Café                  Shopping Mall
# 95                         Park                           Café
# 98                         Café            Fried Chicken Joint
# 100             Supplement Shop                  Shopping Mall
#
#          4th Most Common Venue          5th Most Common Venue  \
# 0                          Spa              Martial Arts Dojo
# 1                          Bar                  Women's Store
# 4                  Yoga Studio            Rental Car Location
# 5            Convenience Store                     Restaurant
# 6                Grocery Store              Convenience Store
# 7                       Bakery              Convenience Store
# 8       Furniture / Home Store                           Park
# 10          Chinese Restaurant           Fast Food Restaurant
# 11         Rental Car Location         Furniture / Home Store
# 12             Motorcycle Shop                    Supermarket
# 13                        Park                   Noodle House
# 14          Chinese Restaurant                      BBQ Joint
# 15              Breakfast Spot                         Bakery
# 17              Ice Cream Shop             Chinese Restaurant
# 18        Fast Food Restaurant                           Bank
# 19                        Café                   Skating Rink
# 20                Tennis Court                        Exhibit
# 21                        Park                           Café
# 22            Ramen Restaurant           Fast Food Restaurant
# 23                Tennis Court                           Bank
# 24                     Butcher                       Pharmacy
# 28               Deli / Bodega            Fried Chicken Joint
# 29                  Sports Bar      Middle Eastern Restaurant
# 30   Latin American Restaurant                           Park
# 31                         Spa          Vietnamese Restaurant
# 32                  Restaurant                  Women's Store
# 33                 Coffee Shop            American Restaurant
# 34                 Coffee Shop            Sporting Goods Shop
# 35                      Bakery                           Bank
# 36          Athletics & Sports                       Bus Line
# ..                         ...                            ...
# 53                        Café             Italian Restaurant
# 56                  Restaurant                            Pub
# 58         American Restaurant                Thai Restaurant
# 59                    Aquarium                     Restaurant
# 60                  Restaurant            American Restaurant
# 61                  Restaurant                   Concert Hall
# 63                      Garden                        Exhibit
# 66                      Bakery  Vegetarian / Vegan Restaurant
# 67                      Bakery                   Dessert Shop
# 70                  Restaurant            American Restaurant
# 71                  Restaurant          Vietnamese Restaurant
# 72                Tennis Court                 Hardware Store
# 73           Korean Restaurant                 Sandwich Place
# 74        Fast Food Restaurant                     Beer Store
# 75                 Pizza Place              Indian Restaurant
# 78         Arts & Crafts Store         Furniture / Home Store
# 80                   Wine Shop                    Coffee Shop
# 81          Athletics & Sports                           Park
# 82                      Bakery                   Antique Shop
# 83            Sushi Restaurant                 Breakfast Spot
# 84                      Bakery             Italian Restaurant
# 85                        Café               Sushi Restaurant
# 86            Asian Restaurant                    Pizza Place
# 87                 Coffee Shop                         Bakery
# 89                         Pub                       Pharmacy
# 92              Sandwich Place              Convenience Store
# 93                        Bank                           Park
# 95                  Beer Store                    Coffee Shop
# 98                 Pizza Place                 Breakfast Spot
# 100             Sandwich Place            American Restaurant
#
#              6th Most Common Venue                     7th Most Common Venue  \
# 0    Paper / Office Supplies Store                                Hobby Shop
# 1                Electronics Store                                  Dive Bar
# 4                     Burger Joint                                  Bus Line
# 5                      Coffee Shop                          Hakka Restaurant
# 6                 Department Store                              Intersection
# 7                      Bus Station                              Intersection
# 8                     Burger Joint                             Women's Store
# 10                     Wings Joint                               Coffee Shop
# 11                     Fish Market                         Korean Restaurant
# 12                  Sandwich Place                            Discount Store
# 13              Seafood Restaurant                           Thai Restaurant
# 14             Fried Chicken Joint                               Coffee Shop
# 15                  Sandwich Place                       Japanese Restaurant
# 17               Recreation Center  Residential Building (Apartment / Condo)
# 18                   Shopping Mall                                Restaurant
# 19                   Grocery Store                         Convenience Store
# 20                     Event Space                                      Farm
# 21                  Sandwich Place                             Shopping Mall
# 22                Sushi Restaurant                            Sandwich Place
# 23             Dumpling Restaurant                        Dim Sum Restaurant
# 24                   Women's Store                                Donut Shop
# 28              Frozen Yogurt Shop                                      Bank
# 29             Japanese Restaurant                                      Bank
# 30              Turkish Restaurant                            Sandwich Place
# 31            Gym / Fitness Center                             Shopping Mall
# 32             Dumpling Restaurant                        Dim Sum Restaurant
# 33                   Shopping Mall                                Beer Store
# 34                    Intersection                                      Park
# 35              Athletics & Sports                            Soccer Stadium
# 36                     Curling Ice                                Restaurant
# ..                             ...                                       ...
# 53                         Theater                                       Pub
# 56             Japanese Restaurant                                      Park
# 58                         Theater                                       Bar
# 59                            Café                                      Park
# 60                       Gastropub                                Steakhouse
# 61             Japanese Restaurant                       American Restaurant
# 63              Falafel Restaurant                              Dessert Shop
# 66                     Pizza Place                           Thai Restaurant
# 67           Vietnamese Restaurant                        Chinese Restaurant
# 70                      Steakhouse                             Deli / Bodega
# 71                    Dessert Shop                               Coffee Shop
# 72                       Pet Store                                       Pub
# 73              Frozen Yogurt Shop                                    Bakery
# 74                          Market                       Sporting Goods Shop
# 75               Convenience Store                                     Diner
# 78                          Bakery                        Italian Restaurant
# 80                  Hardware Store                            Sandwich Place
# 81          Furniture / Home Store                            Discount Store
# 82                     Coffee Shop                             Deli / Bodega
# 83                     Coffee Shop                                      Café
# 84                             Pub                          Sushi Restaurant
# 85                 Bubble Tea Shop                            Sandwich Place
# 86                      Restaurant                 Middle Eastern Restaurant
# 87                   Burrito Place                        Light Rail Station
# 89                            Park                         Convenience Store
# 92              Italian Restaurant                       American Restaurant
# 93                   Grocery Store                              Skating Rink
# 95                     Pizza Place                                  Pharmacy
# 98                   Grocery Store                                  Pharmacy
# 100                   Intersection                               Supermarket
#
#       8th Most Common Venue      9th Most Common Venue  \
# 0        African Restaurant           Community Center
# 1                   Dog Run           Doner Restaurant
# 4               Flower Shop                Music Store
# 5                   Dog Run           Department Store
# 6        Light Rail Station                       Bank
# 7                      Park       Fast Food Restaurant
# 8                Donut Shop             Discount Store
# 10    Vietnamese Restaurant  Latin American Restaurant
# 11             Burger Joint          Convenience Store
# 12      American Restaurant                     Lounge
# 13       Italian Restaurant               Intersection
# 14                 Pharmacy       Caribbean Restaurant
# 15   Thrift / Vintage Store             Cosmetics Shop
# 17           Sandwich Place                      Diner
# 18              Supermarket                 Food Court
# 19       Chinese Restaurant                 Restaurant
# 20             Dessert Shop         Dim Sum Restaurant
# 21        Electronics Store                 Ski Chalet
# 22          Bubble Tea Shop                       Café
# 23                    Diner             Discount Store
# 24             Dessert Shop         Dim Sum Restaurant
# 28                    Diner                 Restaurant
# 29                      Bar         Miscellaneous Shop
# 30               Donut Shop         Dim Sum Restaurant
# 31                     Bank              Moving Target
# 32                    Diner             Discount Store
# 33             Liquor Store             Discount Store
# 34         Doner Restaurant               Dessert Shop
# 35       Rock Climbing Spot                  Gastropub
# 36           Cosmetics Shop                Pizza Place
# ..                      ...                        ...
# 53                   Bakery             Cosmetics Shop
# 56             Cocktail Bar         Italian Restaurant
# 58             Concert Hall                 Steakhouse
# 59             Concert Hall                    Brewery
# 60            Deli / Bodega         Italian Restaurant
# 61                Gastropub              Deli / Bodega
# 63       Dim Sum Restaurant                      Diner
# 66            Burrito Place                        Bar
# 67              Coffee Shop         Mexican Restaurant
# 70                Gastropub           Asian Restaurant
# 71      Fried Chicken Joint                Flea Market
# 72      Rental Car Location             Discount Store
# 73            Deli / Bodega               Dance Studio
# 74                     Bank                     Bakery
# 75                     Café               Cocktail Bar
# 78                BBQ Joint                      Hotel
# 80             Dessert Shop             Discount Store
# 81                      Bar            Thai Restaurant
# 82                     Park         Mexican Restaurant
# 83               Restaurant                  Bookstore
# 84                Gastropub                      Diner
# 85      Japanese Restaurant                    Gay Bar
# 86       Mexican Restaurant           Sushi Restaurant
# 87       Italian Restaurant            Harbor / Marina
# 89           Sandwich Place               Dance Studio
# 92            Burrito Place               Burger Joint
# 93               Playground          Electronics Store
# 95        Convenience Store               Liquor Store
# 98      Dumpling Restaurant                      Diner
# 100              Beer Store                   Bus Line
#
#         10th Most Common Venue
# 0                      Dog Run
# 1                   Donut Shop
# 4                       Lounge
# 5                Design Studio
# 6          Rental Car Location
# 7                 Soccer Field
# 8                     Dive Bar
# 10        Gym / Fitness Center
# 11                  Smoke Shop
# 12            Malay Restaurant
# 13               Shopping Mall
# 14                Noodle House
# 15        Other Great Outdoors
# 17               Shopping Mall
# 18               Movie Theater
# 19               Shopping Mall
# 20                       Diner
# 21   Middle Eastern Restaurant
# 22           Korean Restaurant
# 23                    Dive Bar
# 24                       Diner
# 28           Other Repair Shop
# 29        Fast Food Restaurant
# 30                       Diner
# 31                       Diner
# 32                    Dive Bar
# 33              Sandwich Place
# 34          Dim Sum Restaurant
# 35                Intersection
# 36                 Video Store
# ..                         ...
# 53                         Bar
# 56                      Bakery
# 58                   Gastropub
# 59              Scenic Lookout
# 60             Thai Restaurant
# 61          Seafood Restaurant
# 63              Discount Store
# 66                         Pub
# 67         Dumpling Restaurant
# 70                    Beer Bar
# 71         Rental Car Location
# 72                    Bus Line
# 73          Italian Restaurant
# 74              Discount Store
# 75                         Pub
# 78           French Restaurant
# 80               Grocery Store
# 81              Sandwich Place
# 82                 Pizza Place
# 83         American Restaurant
# 84          Falafel Restaurant
# 85                         Spa
# 86         Fried Chicken Joint
# 87                 Pizza Place
# 89                Skating Rink
# 92   Middle Eastern Restaurant
# 93                     Exhibit
# 95              Discount Store
# 98              Discount Store
# 100                Pizza Place
#
# [71 rows x 12 columns]

# %% [markdown]
# *Examine Cluster 4*

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4,toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 2        Scarborough               4           Pizza Place
# 3        Scarborough               4           Coffee Shop
# 16       Scarborough               4                   NaN
# 25        North York               4              Bus Stop
# 26        North York               4   Japanese Restaurant
# 46   Central Toronto               4   Sporting Goods Shop
# 51  Downtown Toronto               4            Restaurant
# 54  Downtown Toronto               4           Coffee Shop
# 55  Downtown Toronto               4           Coffee Shop
# 57  Downtown Toronto               4           Coffee Shop
# 62        North York               4    Italian Restaurant
# 68  Downtown Toronto               4       Harbor / Marina
# 76      West Toronto               4           Coffee Shop
# 90         Etobicoke               4      Sushi Restaurant
# 91         Etobicoke               4        Baseball Field
# 94         Etobicoke               4                 Hotel
# 97        North York               4     Convenience Store
#
#      2nd Most Common Venue   3rd Most Common Venue  \
# 2              Coffee Shop    Fast Food Restaurant
# 3                     Park        Business Service
# 16                     NaN                     NaN
# 25  Furniture / Home Store                    Park
# 26                    Pool    Gym / Fitness Center
# 46             Coffee Shop      Italian Restaurant
# 51             Coffee Shop                    Café
# 54          Clothing Store              Restaurant
# 55                    Café                   Hotel
# 57                    Café         Bubble Tea Shop
# 62             Coffee Shop        Sushi Restaurant
# 68           Boat or Ferry        Airport Terminal
# 76                    Park                  Bakery
# 90          Breakfast Spot                    Park
# 91           Poutine Place             Art Gallery
# 94             Pizza Place                    Bank
# 97          Discount Store  Furniture / Home Store
#
#          4th Most Common Venue          5th Most Common Venue  \
# 2             Greek Restaurant                       Pharmacy
# 3          Dumpling Restaurant             Dim Sum Restaurant
# 16                         NaN                            NaN
# 25                        Road              Food & Drink Shop
# 26        Caribbean Restaurant  Paper / Office Supplies Store
# 46                        Café                          Diner
# 51                 Pizza Place                       Pharmacy
# 54                       Plaza                      Gastropub
# 55                  Restaurant             Italian Restaurant
# 57                Burger Joint             Italian Restaurant
# 62                   Juice Bar           Fast Food Restaurant
# 68         Rental Car Location               Sculpture Garden
# 76                    Pharmacy                            Gym
# 90          Italian Restaurant              Mobile Phone Shop
# 91  Construction & Landscaping                           Park
# 94           Convenience Store             Mexican Restaurant
# 97              Baseball Field              Electronics Store
#
#           6th Most Common Venue  7th Most Common Venue 8th Most Common Venue  \
# 2                    Sports Bar            Supermarket   Fried Chicken Joint
# 3                         Diner         Discount Store              Dive Bar
# 16                          NaN                    NaN                   NaN
# 25             Doner Restaurant     Dim Sum Restaurant                 Diner
# 26                         Café   Ethiopian Restaurant   Empanada Restaurant
# 46                  Yoga Studio            Pizza Place                   Spa
# 51                       Bakery                    Pub            Beer Store
# 54                     Tea Room                   Café       Thai Restaurant
# 55                       Bakery         Cosmetics Shop        Breakfast Spot
# 57                        Diner     Chinese Restaurant      Sushi Restaurant
# 62                 Skating Rink             Baby Store            Bagel Shop
# 68               Airport Lounge        Airport Service           Coffee Shop
# 76                Grocery Store  Portuguese Restaurant           Supermarket
# 90                  Coffee Shop             Restaurant      Business Service
# 91  Eastern European Restaurant         Discount Store              Dive Bar
# 94                      Theater    American Restaurant                  Café
# 97                     Dive Bar                Dog Run      Doner Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 2             Beer Store          Grocery Store
# 3                Dog Run       Doner Restaurant
# 16                   NaN                    NaN
# 25        Discount Store               Dive Bar
# 26          Dessert Shop     Dim Sum Restaurant
# 46          Skating Rink     Salon / Barbershop
# 51                 Diner        Thai Restaurant
# 54                 Hotel                  Diner
# 55    Seafood Restaurant              Gastropub
# 57    Falafel Restaurant                    Spa
# 62                Bakery                   Bank
# 68                  Park            Music Venue
# 76        Discount Store                   Café
# 90                 River                    Bar
# 91               Dog Run       Doner Restaurant
# 94           Coffee Shop         Clothing Store
# 97            Donut Shop    Dumpling Restaurant

# %% [markdown]
# *Consolidating the results into pivot table, showing clusters and their most common venue unique values*

# %%
toronto_0=pd.DataFrame(toronto_merged, columns=['Cluster Labels', '1st Most Common Venue'])
toronto_0.dropna(inplace=True)
pd.pivot_table(toronto_0, index=['Cluster Labels','1st Most Common Venue'], aggfunc = 'count' )
# Out:
# Empty DataFrame
# Columns: []
# Index: [(0, Café), (1, Bakery), (1, Café), (1, Coffee Shop), (1, College Stadium), (1, Indian Restaurant), (1, Pizza Place), (2, Café), (3, BBQ Joint), (3, Bank), (3, Bar), (3, Breakfast Spot), (3, Café), (3, Chinese Restaurant), (3, Clothing Store), (3, Coffee Shop), (3, Convenience Store), (3, Diner), (3, Electronics Store), (3, Fast Food Restaurant), (3, Furniture / Home Store), (3, Greek Restaurant), (3, Grocery Store), (3, Health Food Store), (3, Hotel), (3, Indian Restaurant), (3, Japanese Restaurant), (3, Korean Restaurant), (3, Park), (3, Pet Store), (3, Pharmacy), (3, Pizza Place), (3, Pool), (3, Sandwich Place), (3, Skating Rink), (3, Vietnamese Restaurant), (4, Baseball Field), (4, Bus Stop), (4, Coffee Shop), (4, Convenience Store), (4, Harbor / Marina), (4, Hotel), (4, Italian Restaurant), (4, Japanese Restaurant), (4, Pizza Place), (4, Restaurant), (4, Sporting Goods Shop), (4, Sushi Restaurant)]

# %% [markdown]
# - **Results section**
#
# The results derived from clustering with K-mean algorithm (with K equal to 5) shows that most common venues in first and third cluster are cafes. Fourth cluster venues should be related with Toronto's downtown because objects like banks, stores and some hotels are often associated with central business district. Second cluster venues probably belongs to an area closer to the downtown as it has many cafes and restaurants. Finally, the fifth cluster indicates more distant, suburb areas. Such suggestion is based on the fact that many of its venues are bus stops, sporting facilities, even harbor.

# %% [markdown]
# - **Discussion section**
#
# Foursquare data combined with K-mean algorithm provide data analyst with a powerful tool to understand how the modern city works. By plotting the venues the analyst could get a general idea how the city is structured, thus enables him to 'visit' places he never been before.
# Concerning Toronto's data as already mentioned in the results part some general suggestions could be made. First, the most visited city places are located in the central area or closer to it. Second, the data implies that except the downtown there should be also areas with features similar to the typical suburb areas. Obviously, Toronto's downtown is more suitable for business purposes (offices, stores, hotels, etc.) compared with the other city areas. However, common practice in such agglomerations is wealthy people to settle in more green and distant neighborhoods.

# %% [markdown]
# - **Conclusion section**
#
# Finally, newcomers in Toronto via different government programs are kindly advised to consider properties in fifth cluster. Usually such districts offer more green areas, pretty houses, good transportation services hence better living quality. Should be also mentioned that there is harbor in the last cluster. As a rule of thumb properties near harbors deem to be luxury and well managed.
